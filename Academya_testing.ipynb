# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.express as px

# %%
train = pd.read_csv(r'C:\Users\HP\KaggleDatasets\train_academya.csv')
test = pd.read_csv(r'C:\Users\HP\KaggleDatasets\test_academya.csv')

# %%
missing_percentagetrain = (train.isnull().sum() / len(train)) * 100
missing_percentagetest = (test.isnull().sum() / len(train)) * 100

# %%
missing_percentagetrain = missing_percentagetrain[missing_percentagetrain > 0].sort_values(ascending=False)
missing_percentagetest = missing_percentagetest[missing_percentagetest > 0].sort_values(ascending=False)

# %%
missing_percentagetrain
# Out:
# id                            0.000000
# having_ip_address             7.703905
# url_length                    0.000000
# shortining_service            3.882105
# having_at_symbol              7.522237
# double_slash_redirecting      0.000000
# prefix_suffix                 4.522840
# having_sub_domain             0.000000
# domain_registration_length    0.000000
# favicon                       5.795266
# port                          3.606211
# https_token                   6.867933
# request_url                   0.000000
# url_of_anchor                 0.000000
# links_in_tags                 0.000000
# sfh                           4.537916
# submitting_to_email           3.267752
# abnormal_url                  4.294437
# redirect                      0.000000
# on_mouseover                  6.368913
# rightclick                    6.723202
# popupwindow                   4.335142
# iframe                        3.191618
# age_of_domain                 0.000000
# ...
